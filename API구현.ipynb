# %%
#!/bin/python3

import math
import os
import random
import re
import sys


#
# Complete the 'getTotalGoals' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. STRING team
#  2. INTEGER year
#
import requests
import json

def getTotalGoals(team, year):
    team = team.lower()
    # print(team, year)
    # headers = {'Content-Type' : 'application/json', 'charset' : 'UTF-8', 'Accept' : '*/*'}
    result = 0
    for team_num in range(1,3):
        url = f"https://jsonmock.hackerrank.com/api/football_matches?year={year}&team{team_num}={team}&page=1"
        response = requests.get(url).json()
        # print(response.text)
        # print(response)
        for page in range(1, response['total_pages'] + 1):
            url = f"https://jsonmock.hackerrank.com/api/football_matches?year={year}&team{team_num}={team}&page={page}"
            new_res = requests.get(url).json()
            for match in new_res['data']:
                if match['team1'].lower() == team:
                    result += int(match['team1goals'])
                elif match['team2'].lower() == team:
                    result += int(match['team2goals'])
                # print(match['team1'], match['team2'], match['team1goals'], match['team2goals'], result)
    return result
    # Write your code here
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    team = input()

    year = int(input().strip())

    result = getTotalGoals(team, year)

    fptr.write(str(result) + '\n')

    fptr.close()
# Out:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



#
# Complete the 'getWinnerTotalGoals' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. STRING competition
#  2. INTEGER year
#
import requests

def getWinnerTotalGoals(competition, year):
    result = 0
    url = f'https://jsonmock.hackerrank.com/api/football_competitions?name={competition}&year={year}'
    winner = requests.get(url).json()['data'][0]['winner']
    for team_num in range(1, 3):
        url = f'https://jsonmock.hackerrank.com/api/football_matches?competition={competition}&year={year}&team{team_num}={winner}&page=1'
        # url = url.replace(' ', '%20')
        # print(url)
        # print(requests.get(url).text)
        for page in range(1, requests.get(url).json()['total_pages']+1):
            url = f'https://jsonmock.hackerrank.com/api/football_matches?competition={competition}&year={year}&team{team_num}={winner}&page={page}'
            # url = url.replace(' ', '%20')
            # print(url)
            response = requests.get(url).json()
            for data in response['data']:
                if data['team1'].lower() == winner.lower():
                    result += int(data['team1goals'])
                elif data['team2'].lower() == winner.lower():
                    result += int(data['team2goals'])
    
    return result
                
        
    # Write your code here

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    competition = input()

    year = int(input().strip())

    result = getWinnerTotalGoals(competition, year)

    fptr.write(str(result) + '\n')

    fptr.close()
